# %% [markdown]
# # prepare source code

# %%
# !unzip image-captioning.zip
# Out:
# Cloning into 'image-captioning'...
# remote: Enumerating objects: 830, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 830 (delta 90), reused 82 (delta 40), pack-reused 694
# Receiving objects: 100% (830/830), 137.37 KiB | 5.49 MiB/s, done.
# Resolving deltas: 100% (454/454), done.

# %% [markdown]
# # install package

# %%
# !pip install yacs
# !pip install datasets
# !pip install transformers
# !pip install sacremoses
# !pip install SentencePiece
# !pip install nltk
# !pip install huggingface_hub
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# !pip install accelerate bitsandbytes
# !pip install peft==0.7.0
# !sudo apt install unzip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 8.4 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # prepare data

# %%
from huggingface_hub import hf_hub_download
hf_hub_download(repo_id="minhquan6203/medical_captioning", filename="data.zip", local_dir='./' ,repo_type="dataset")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# data.zip:   0%|          | 0.00/7.85G [00:00<?, ?B/s]
# 'data.zip'

# %%
# !unzip -qq data.zip

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %% [markdown]
# # training
#
# VisionDiagnostor-Q-BioMistral: image-captioning/config/config_blip2.yaml
#
# VisionDiagnostor-ClinicalT5: image-captioning/config/config_vision_lm.yaml
#
# VisionDiagnostor-BioBART: image-captioning/config/config_biobart.yaml

# %%
# !python3 image-captioning/src/main.py --config image-captioning/config/config_vision_lm.yaml
# Out:
# 2024-05-03 04:00:24.934233: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 04:00:24.934284: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 04:00:24.935687: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 04:00:26.024410: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:root:Training started...
# ...
